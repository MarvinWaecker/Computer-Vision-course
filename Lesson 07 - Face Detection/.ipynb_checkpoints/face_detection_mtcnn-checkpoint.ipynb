# %% [markdown]
# # Face Detection with mtcnn on a photograph

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN

# %% [markdown]
# ### Data

# %%
# load image
pixels = pyplot.imread('dinner.jpg')

# %% [markdown]
# ### Model

# %%
# create the detector, using default weights
detector = MTCNN()

# %%
# detect faces in the image
faces = detector.detect_faces(pixels)
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3878df160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# plot the image
pyplot.imshow(pixels)
# get the context for drawing boxes
ax = pyplot.gca()
# get coordinates from the first face
for face in faces:
    x, y, width, height = face['box']
    # create the shape
    rect = Rectangle((x, y), width, height, fill=False, edgecolor='red', lw=2)
    print(x, y)
    # draw the box
    ax.add_patch(rect)
# show
pyplot.show()
# Out:
# 496 62
# 275 79
# 556 129
# 73 85
# 768 132
# 229 299
